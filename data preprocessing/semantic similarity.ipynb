# %%
import pandas as pd
from sentence_transformers import SentenceTransformer, util

model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")

df = pd.read_csv("/content/clean_data.csv")

# %%
def get_similarity(a, b):
    emb1 = model.encode(a, convert_to_tensor=True)
    emb2 = model.encode(b, convert_to_tensor=True)
    return float(util.cos_sim(emb1, emb2))

# %%
scores = []
flags = []

for i, row in df.iterrows():
    complaint = str(row["input"])
    diagnosis = str(row["output"])

    score = get_similarity(complaint, diagnosis)
    scores.append(score)

    flags.append(score > 0.30)

df["similarity_score"] = scores
df["not_logical"] = flags

# %%
df.to_csv("checked_results2.csv", index=False)

# %%
df
# Out:
#                                                   input  \
# 0     doctor i have been experiencing sudden and fre...
# 1     doctor i have been experiencing a hoarse voice...
# 2        hi doctor i think i might have turner syndrome
# 3     doctor ive been experiencing a condition calle...
# 4     doctor i think ive been poisoned i drank some ...
# ...                                                 ...
# 5447  doctor i have an open wound in my nose and i a...
# 5448  doctor i have an open wound in my nose and my ...
# 5449  doctor i have an open wound on my nose and im ...
# 5450  doctor i have a sore in my nose and i keep get...
# 5451  doctor i have an open wound on my nose and i a...
#
#                                                  output  similarity_score  \
# 0     well based on what youre telling me it sounds ...          0.686802
# 1     its possible that you have a vocal cord polyp ...          0.548625
# 2     okay in that case you will need to undergo a c...          0.299162
# 3     you will need to undergo a complete physical s...          0.590608
# 4     im sorry to hear that we need to run a few tes...          0.572287
# ...                                                 ...               ...
# 5447  based on your symptoms you may have a complica...          0.736338
# 5448  based on your symptoms you may have a staph in...          0.744922
# 5449  hot flashes are a common symptom of menopause ...          0.824751
# 5450  it sounds like you have an open wound in your ...          0.708361
# 5451  it seems like you have an infection in your no...          0.851918
#
#       not_logical
# 0            True
# 1            True
# 2           False
# 3            True
# 4            True
# ...           ...
# 5447         True
# 5448         True
# 5449         True
# 5450         True
# 5451         True
#
# [5452 rows x 4 columns]

# %%
df_false = df[df["not_logical"] == False]

df_false
# Out:
#                                                   input  \
# 2        hi doctor i think i might have turner syndrome
# 24    doctor i am experiencing some problems during ...
# 33    doctor i was diagnosed with congenital rubella...
# 48    doctor my baby has been very fussy and irritab...
# 49    doctor i have been experiencing severe stomach...
# ...                                                 ...
# 5375  doctor i have been experiencing dizziness diff...
# 5424  doctor ive been having heartburn fluid retenti...
# 5425  hi doctor ive been experiencing sharp abdomina...
# 5426  doctor ive been experiencing chills sharp abdo...
# 5431  doctor i have been feeling a weakness in my lo...
#
#                                                  output  similarity_score  \
# 2     okay in that case you will need to undergo a c...          0.299162
# 24    i see in order to diagnose any possible compli...          0.248066
# 33             you need to undergo a corneal transplant          0.186543
# 48    okay well need to perform a complete physical ...          0.228306
# 49    i see in that case we need to run some medical...          0.228594
# ...                                                 ...               ...
# 5375  based on your symptoms it seems that you may b...          0.187981
# 5424  based on your symptoms you may be experiencing...          0.280286
# 5425  yes based on your symptoms it is possible that...          0.272098
# 5426  based on your symptoms its possible that you h...          0.290023
# 5431  based on your symptoms it is possible that you...          0.238961
#
#       not_logical
# 2           False
# 24          False
# 33          False
# 48          False
# 49          False
# ...           ...
# 5375        False
# 5424        False
# 5425        False
# 5426        False
# 5431        False
#
# [260 rows x 4 columns]

# %%
df_false.to_csv("only_false_rows.csv", index=False)
